# %%
import os

# %%
path = os.listdir("./uploads/seorank.pk")

# %%
path
# Out:
# ['4-category-home.md',
#  '1-what-are-ai-powered-seo-tools-a-beginners-guide.md',
#  '7-ai-content-score-vs-true-content-quality-comparison.md',
#  '3-author-husamkazim77gmail-com.md',
#  '2-category-seo.md',
#  '8-ai-driven-seo-analytics-tools-strategic-guide-2025.md',
#  '0-surfer-seo-vs-jasper-vs-semrush-contentshake-ai-best-ai-seo-tool-for-bloggers.md',
#  '9-best-ai-content-scoring-tools-surfer-vs-clearscope.md',
#  '6-category-seo-tools.md',
#  '5-root.md']
